# %%
planet_names = ["水","金","地","火","木","土","天","海","冥"]

for planet_name in planet_names:
  print(planet_name)

array = ["水","金","地","火","木","土","天","海","冥"]

count = 0
while count < 1:
  for planet_name in planet_names:
    print(planet_name)
  count = count + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
